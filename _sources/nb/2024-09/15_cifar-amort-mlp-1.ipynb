# %% [markdown]
# # (15) CIFAR — mlp
#
# **Motivation**: host = ```mach```, device = ```cuda:1``` <br>

# %%
# HIDE CODE


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-vae/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-vae/figs')
tmp_dir = os.path.join(git_dir, 'jb-vae/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_IterativeVAE'))
from figures.fighelper import *
from vae.train_vae import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %%
from base.utils_model import load_quick
from figures.analysis import plot_convergence
from figures.imgs import plot_weights

device_idx = 1
device = f'cuda:{device_idx}'

print(f"device: {device}  ———  host: {os.uname().nodename}")
# Out:
# device: cuda:1  ———  host: mach

# %% [markdown]
# ## Poisson
#
# Dataset: CIFAR10

# %% [markdown]
# ### Get configs

# %%
model_type = 'gaussian'
cfg_vae, cfg_tr = default_configs('CIFAR10', model_type, 'jacob|mlp')

seq_len = 64
cfg_vae['track_stats'] = True
cfg_vae['seq_len'] = seq_len
cfg_vae['n_latents'] = 2000
# cfg_vae['clamp_prior'] = 1.0

cfg_tr['kl_beta'] = 3/8 * seq_len

# %%
cfg_vae
# Out:
# {'dataset': 'CIFAR10',
#  'n_latents': 2000,
#  'clamp_du': 6.0,
#  'clamp_u': 6.5,
#  'enc_type': 'jacob',
#  'dec_type': 'mlp',
#  'init_dist': 'normal',
#  'init_scale': 0.001,
#  'track_stats': True,
#  'seq_len': 64}

# %% [markdown]
# ### Make model + trainer

# %%
vae = MODEL_CLASSES[model_type](CFG_CLASSES[model_type](**cfg_vae))
tr = TrainerVAE(vae, ConfigTrainVAE(**cfg_tr), device=device)

tr.n_iters
# Out:
# 125000

# %% [markdown]
# ### Print info

# %%
vae.print()
print(f"{vae.cfg.name()}\n{tr.cfg.name()}_({vae.timestamp})\n")
tr.show_schedules()
# Out:
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |    IGVAE    |  14.6 Mil  |
# |     ———     |    ———     |
# |    layer    |  14.6 Mil  |
# +-------------+------------+
# gaussian_CIFAR10_t-64_z-[2000]_<jacob|mlp>
# b80-ep200-lr(0.0001)_beta(24:0x0.1)_gr(2000)_(2024_09_20,20:23)

# %%
print_num_params(tr.model.layer)
# Out:
# +---------------+------------+
# |  Module Name  | Num Params |
# +---------------+------------+
# | GaussianLayer |  14.6 Mil  |
# |      ———      |    ———     |
# |      dec      |  14.6 Mil  |
# +---------------+------------+

# %%
# vae.layer.n_exp

# %%
vae.cfg.track_stats
# Out:
# True

# %%
print(f"{vars(tr.model.cfg)}\n\n\n{vars(tr.cfg)}")
# Out:
# {'latent_act': None, 'type': 'gaussian', 'n_ch': 32, 'seq_len': 64, 'n_latents': [2000], 'jac_type': 'grad',
# 'enc_type': 'jacob', 'dec_type': 'mlp', 'dataset': 'CIFAR10', 'input_sz': (3, 32, 32), 'res_eps': 1.0, 'clamp_u':
# 6.5, 'clamp_du': 6.0, 'init_dist': 'normal', 'init_scale': 0.001, 'activation_fn': 'swish', 'fit_prior': True,
# 'residual': True, 'use_bn': False, 'use_se': True, 'track_stats': True, 'seed': 0, 'base_dir':
# '/home/hadi/Projects/PoissonVAE', 'data_dir': '/home/hadi/Datasets', 'runs_dir':
# '/home/hadi/Projects/PoissonVAE/runs/gaussian_CIFAR10_t-64_z-[2000]_<jacob|mlp>', 'mods_dir':
# '/home/hadi/Projects/PoissonVAE/models/gaussian_CIFAR10_t-64_z-[2000]_<jacob|mlp>', 'results_dir':
# '/home/hadi/Projects/PoissonVAE/results'}
#
#
# {'lr': 0.0001, 'epochs': 200, 'batch_size': 80, 'file_name': None, 'warm_restart': 0, 'warmup_epochs': 1,
# 'optimizer': 'adamax_fast', 'optimizer_kws': {'weight_decay': 0.0003, 'betas': (0.9, 0.999), 'eps': 1e-08},
# 'scheduler_type': 'cosine', 'scheduler_kws': {'eta_min': 1e-06, 'T_max': 199.0}, 'ema_rate': None, 'grad_clip':
# 2000, 'chkpt_freq': 10, 'eval_freq': 20, 'log_freq': 10, 'method': 'mc', 'kl_beta': 24.0, 'kl_beta_min': 0.0001,
# 'kl_balancer': None, 'kl_time_adjuster': None, 'kl_anneal_cycles': 0, 'kl_anneal_portion': 0.1, 'kl_const_portion':
# 0.001, 'temp_anneal_portion': 0.0, 'temp_anneal_type': 'lin', 'temp_start': 1.0, 'temp_stop': 1.0}

# %% [markdown]
# ### Fit model

# %%
tr.train()
# Out:
# epoch # 194, avg loss: 334.577472:  97%|█▉| 194/200 [13:28:32<25:00, 250.07s/it]

# %% [markdown]
# **Task:** CIFAR10, gaussian ```<jacob|mlp>```, 2000-dim latent space, $(T, \beta) = (1, 1.0)$, ```lr=1e-4```

# %%
# tr, meta = load_model(
#     'poisson_CIFAR10_t-32_z-[512]_k-32_<jacob|conv>',
#     'b100-ep250-lr(0.0001)_beta(16:0x0.1)_temp(0.05:lin-0.5)_gr(1500)_(2024_09_17,08:50)',
#     device=device,
# )

# %%
# print(tr.model.layer.n_exp)

# %%
u_max = np.array(tr.model.stats['u_max'])
du_max = np.array(tr.model.stats['du_max'])

u_max.max(), du_max.max()
# Out:
# (415.68658447265625, 416.9891357421875)

# %%
fig, axes = create_figure(2, 2, sharey='row')

axes[0, 0].plot(u_max, color='C7', lw=0.1, label='u_max')
axes[0, 1].plot(du_max, color='C4', lw=0.1, label='du_max')
axes[0, 1].set(ylim=(0, 8))

sns.kdeplot(u_max, color='C7', label='u_max', ax=axes[1, 0])
sns.kdeplot(du_max, color='C4', label='du_max', ax=axes[1, 1])

add_legend(axes)
plt.show()

# %%
grad = np.array(list(tr.stats['grad'].values()))
(grad > tr.cfg.grad_clip).sum(), np.round((grad > tr.cfg.grad_clip).mean(), 3)
# Out:
# (63471, 0.508)

# %%
fig, axes = create_figure(1, 3)

axes[0].plot(np.log(grad)[:300], lw=1)
axes[1].plot(np.log(grad), lw=0.1)

axes[2].axvline(np.log(tr.cfg.grad_clip), color='magenta', ls='--')
histplot(np.log(grad), ax=axes[2])

plt.show()

# %%
log_rate = tonp(tr.model.layer.log_rate).ravel()
bias = tonp(tr.model.layer.bias).ravel()

fig, axes = create_figure(1, 2, (10, 2))
kws = dict(fill=True, lw=1, alpha=0.3, ax=axes[0])
sns.histplot(log_rate, color='C0', element='step', label=r'$\log r$', **kws)

kws = dict(fill=True, lw=1, alpha=0.3, ax=axes[1])
sns.histplot(np.exp(log_rate), color='C0', element='step', label='rate', **kws)
sns.histplot(bias, color='C8', element='step', label='bias', **kws)

axes[1].set(ylabel='')
add_legend(axes)

plt.show()

# %%
dead = log_rate > 5
dead.sum(), (~dead).sum(), dead.sum() / len(dead)
# Out:
# (0, 2000, 0.0)

# %%
# %%time

kws = dict(
    seq_total=2000,
    seq_batch_sz=100,
    n_data_batches=2,
    # active=~dead,
)
results = tr.analysis(dl='vld', **kws)
_ = plot_convergence(results, color='teal')
# Out:
# 100%|███████████████████████████████████| 2/2 [00:16<00:00,  8.00s/it]
# CPU times: user 18.1 s, sys: 2.13 s, total: 20.2 s
# Wall time: 21 s

# %%
kws = dict(
    seq_total=tr.model.cfg.seq_len,
    seq_batch_sz=100,
    n_data_batches=1,
    # active=~dead,
    return_recon=True,
    full_data=True,
    verbose=False,
)
results_to_plot = {
    name: tr.analysis(dl=name, **kws)
    for name in ['trn', 'vld']
}

# %%
num = 32

x2p_dict = {}
for name, d in results_to_plot.items():
    x2p = np.concatenate([
        d['x'][:num],
        d['y'][:num, -1].reshape(-1, *tr.model.cfg.input_sz),
    ])
    x2p = (x2p + 1) / 2
    x2p = np.clip(x2p, 0, 1)
    x2p_dict[name] = x2p

# %%
name = 'vld'

fig, axes = create_figure(2, 24, (24, 2))
for i in range(24):
    axes[0, i].imshow(x2p_dict[name][i].transpose(1, 2, 0))
    axes[1, i].imshow(x2p_dict[name][i + 32].transpose(1, 2, 0))
remove_ticks(axes)
plt.show()

# %%
posterior_log_rates = collections.defaultdict(list)
for x, *_ in iter(tr.dl_vld):
    output = tr.model.xtract_ftr(x)
    for t, pois in output['dist'].items():
        posterior_log_rates[t].append(torch.log(pois.rate))
posterior_log_rates = {
    t: tonp(torch.cat(v)) for t, v
    in posterior_log_rates.items()
}


fig, ax = create_figure(1, 1, (10, 3.5))
pal = get_cubehelix_palette(tr.model.cfg.seq_len, start=2.5)

for i, (t, v) in enumerate(posterior_log_rates.items()):
    sns.histplot(
        v[:, ~dead].ravel(),
        stat='percent',
        element='step',
        fill=False,
        color=pal[i],
        label=f"T = {t}",
        ax=ax,
    )
# ax.legend()
ax.grid()
plt.show()


fig, axes = create_figure(2, 1, (6, 4.2), sharex='col')
for i, (t, v) in enumerate(posterior_log_rates.items()):
    for ax in axes.flat:
        sns.histplot(
            np.exp(v[:, ~dead].ravel()),
            stat='percent',
            element='step',
            fill=False,
            color=pal[i],
            label=f"T = {t}",
            ax=ax,
        )
axes[1].set(yscale='log')
add_grid(axes)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 33
#      31 for i, (t, v) in enumerate(posterior_log_rates.items()):
#      32     for ax in axes.flat:
# ---> 33         sns.histplot(
#      34             np.exp(v[:, ~dead].ravel()),
#      35             stat='percent',
#      36             element='step',
#      37             fill=False,
#      38             color=pal[i],
#      39             label=f"T = {t}",
#      40             ax=ax,
#      41         )
#      42 axes[1].set(yscale='log')
#      43 add_grid(axes)
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/distributions.py:1389, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1386 if ax is None:
#    1387     ax = plt.gca()
# -> 1389 p._attach(ax, log_scale=log_scale)
#    1391 if p.univariate:  # Note, bivariate plots won't cycle
#    1392     if fill:
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/_base.py:1128, in VectorPlotter._attach(self, obj, allowed_types, log_scale)
#    1126 # Now actually update the matplotlib objects to do the conversion we want
#    1127 grouped = self.plot_data[var].groupby(self.converters[var], sort=False)
# -> 1128 for converter, seed_data in grouped:
#    1129     if self.var_types[var] == "categorical":
#    1130         if self._var_ordered[var]:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:603, in BaseGrouper.get_iterator(self, data, axis)
#     592 def get_iterator(
#     593     self, data: NDFrameT, axis: AxisInt = 0
#     594 ) -> Iterator[tuple[Hashable, NDFrameT]]:
#     595     """
#     596     Groupby iterator
#     597
#    (...)
#     601     for each group
#     602     """
# --> 603     splitter = self._get_splitter(data, axis=axis)
#     604     keys = self.group_keys_seq
#     605     yield from zip(keys, splitter)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:619, in BaseGrouper._get_splitter(self, data, axis)
#     609 """
#     610 Returns
#     611 -------
#     612 Generator yielding subsetted objects
#     613 """
#     614 ids, _, ngroups = self.group_info
#     615 return _get_splitter(
#     616     data,
#     617     ids,
#     618     ngroups,
# --> 619     sorted_ids=self._sorted_ids,
#     620     sort_idx=self._sort_idx,
#     621     axis=axis,
#     622 )
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:942, in BaseGrouper._sorted_ids(self)
#     938 @final
#     939 @cache_readonly
#     940 def _sorted_ids(self) -> npt.NDArray[np.intp]:
#     941     ids, _, _ = self.group_info
# --> 942     return ids.take(self._sort_idx)
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:936, in BaseGrouper._sort_idx(self)
#     931 @final
#     932 @cache_readonly
#     933 def _sort_idx(self) -> npt.NDArray[np.intp]:
#     934     # Counting sort indexer
#     935     ids, _, ngroups = self.group_info
# --> 936     return get_group_index_sorter(ids, ngroups)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/sorting.py:721, in get_group_index_sorter(group_index, ngroups)
#     719 do_groupsort = count > 0 and ((alpha + beta * ngroups) < (count * np.log(count)))
#     720 if do_groupsort:
# --> 721     sorter, _ = algos.groupsort_indexer(
#     722         ensure_platform_int(group_index),
#     723         ngroups,
#     724     )
#     725     # sorter _should_ already be intp, but mypy is not yet able to verify
#     726 else:
#     727     sorter = group_index.argsort(kind="mergesort")
#
# KeyboardInterrupt:
