# %% [markdown]
# # (17) poisson conditional
#
# **Motivation**: host = ```mach```, device = ```cuda:0``` <br>

# %%
# HIDE CODE


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-vae/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-vae/figs')
tmp_dir = os.path.join(git_dir, 'jb-vae/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_IterativeVAE'))
from figures.fighelper import *
from vae.train_vae import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %%
from analysis.chosen import *
from figures.analysis import *
from figures.imgs import plot_weights

device_idx = 0
device = f'cuda:{device_idx}'

print(f"device: {device}  ———  host: {os.uname().nodename}")
# Out:
# device: cuda:0  ———  host: mach

# %% [markdown]
# ## vH16
#
# Intermediate beta: $(T, \beta) = (8, 1.0)$

# %%
model_type = 'poisson'
cfg_vae, cfg_tr = default_configs('vH16', model_type, 'jacob|lin')

cfg_vae['track_stats'] = True

seq_len = 8
cfg_vae['seq_len'] = seq_len
cfg_vae['clamp_du'] = 5
cfg_vae['clamp_u'] = 5

cfg_tr['kl_beta'] = 1/8 * seq_len
cfg_tr['lr'] = 2e-3

cfg_tr['file_name'] = 'patches_quantized.npy'

# %%
vae = MODEL_CLASSES[model_type](CFG_CLASSES[model_type](**cfg_vae))
tr = TrainerVAE(vae, ConfigTrainVAE(**cfg_tr), device=device)
print_num_params(vae.layer)

print(f"{vae.cfg.name()}\n{tr.cfg.name()}_({vae.timestamp})\n")
tr.n_iters
# Out:
# +--------------+------------+
# | Module Name  | Num Params |
# +--------------+------------+
# | PoissonLayer |  132.1 K   |
# |     ———      |    ———     |
# |     phi      |  131.1 K   |
# +--------------+------------+
# poisson_vH16_t-8_z-[512]_<jacob|lin>
# b200-ep300-lr(0.002)_beta(1:0x0.1)_temp(0.05:lin-0.5)_gr(200)_(2024_10_17,19:04)
# 297900

# %%
tr.show_schedules();

# %%
x = tr.dl_vld.dataset.tensors[0]
x.shape
# Out:
# torch.Size([49604, 1, 16, 16])

# %%
x.min(), x.max()
# Out:
# (tensor(3., device='cuda:0'), tensor(255., device='cuda:0'))

# %%
histplot(x.ravel(), bins=np.linspace(0, 256) - 0.5, color='k')
# Out:
# <Axes: ylabel='Count'>

# %%
len(tr.dl_trn.dataset.tensors[0]) + len(tr.dl_vld.dataset.tensors[0])
# Out:
# 248217

# %%
tr.train()
# Out:
# epoch # 300, avg loss: 41482.257840: 100%|██| 300/300 [5:38:40<00:00, 67.74s/it]

# %% [markdown]
# ### Load

# %%
tr, meta = load_model(
    'poisson_vH16_t-8_z-[512]_<jacob|lin>',
    'b200-ep300-lr(0.002)_beta(3:0x0.1)_temp(0.05:lin-0.5)_gr(200)_(2024_10_17,14:17)',
    device=device,
)
meta['checkpoint']

# %%
log_rate = tonp(tr.model.layer.log_rate.squeeze())
histplot(log_rate, color='b');

# %%
_ = tr.model.show('phi', order=np.argsort(log_rate))

# %%
bias = tonp(tr.model.layer.bias.squeeze())
histplot(bias, color='C8');

# %%
w = tr.model.layer.get_weight()
norms = tonp(torch.linalg.vector_norm(w, dim=0))
order = np.argsort(norms)

_ = tr.model.show(order=order)

histplot(np.log(norms), label='log norm', color='b');

# %%
# %%time

kws = dict(
    seq_total=1000,
    seq_batch_sz=1000,
    n_data_batches=10,
)
results = tr.analysis(**kws)

_ = plot_convergence(results, color='k')
# Out:
# 100%|█████████████████████████████████| 10/10 [05:50<00:00, 35.08s/it]
# CPU times: user 6min 2s, sys: 5.93 s, total: 6min 8s
# Wall time: 6min 7s

# %%
x = next(iter(tr.dl_vld))[0]
x.shape
# Out:
# torch.Size([200, 1, 16, 16])

# %%
output = tr.model.xtract_ftr(
    x=x,
    seq=range(24),
    return_extras=True,
).stack()

# %%
list(output)
# Out:
# ['loss_kl',
#  'loss_recon',
#  'posterior',
#  'ff',
#  'recon',
#  'state',
#  'samples',
#  'conditional']

# %%
num = 32

x2p = torch.cat([
    tr.dl_vld.dataset.tensors[0][:num],
    output['recon'][:num, -1].reshape(tr.model.cfg.shape),
])
_ = plot_weights(x2p, nrows=2, cmap='Greys', dpi=500)

# %%
d = output['conditional']['23']

# %%
mse = (x.flatten(start_dim=1) - d.loc) ** 2
mse = torch.sum(mse, dim=1)
mse.mean()
# Out:
# tensor(30.9770, device='cuda:0')

# %%
recon_loss = d.log_prob(x.flatten(start_dim=1)).mul(-1.0)
recon_loss = torch.sum(recon_loss, dim=1)
recon_loss.mean()
# Out:
# tensor(121.9001, device='cuda:0')

# %%
def compute_log_p_x_z(d, x):
    mu, sd = d.loc, d.scale
    zeta = (x - mu) / sd
    nll = 0.5 * zeta ** 2 + torch.log(sd) + 0.5 * np.log(2 * np.pi)
    return nll

# %%
recon_loss = compute_log_p_x_z(d, x.flatten(start_dim=1))
recon_loss = torch.sum(recon_loss, dim=1)
recon_loss.mean()
# Out:
# tensor(121.9001, device='cuda:0')

# %%
divide_integer(1024, (0.5, 0.5))
# Out:
# [512, 512]
