# %% [markdown]
# # (28) DOVES—PoisConv—0
#
# **Motivation**: ```K = 512``` + CONV encoder, with ```rmax_q = 1.00``` to ```DOVES``` dataset. Device = ```cuda:0``` <br>

# %%
# HIDE CODE


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-vae/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-vae/figs')
tmp_dir = os.path.join(git_dir, 'jb-vae/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_PoissonVAE'))
from figures.fighelper import *
from vae.train_vae import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %%
device_idx = 0
device = f'cuda:{device_idx}'

model_type = 'poisson'

# %% [markdown]
# ## Latest implementation (w/ fc encoder layers)

# %%
cfg_vae, cfg_tr = default_configs('DOVES')
cfg_vae['enc_type'] = 'conv'
cfg_vae['enc_bias'] = True
cfg_vae['rmax_q'] = 1.0

print(f"VAE:\n{cfg_vae}\n\nTrainer:\n{cfg_tr}")
# Out:
# VAE:
# {'dataset': 'DOVES', 'prior_clamp': -3.0, 'prior_log_dist': 'uniform', 'rmax_q': 1.0, 'n_latents': 512, 'enc_type':
# 'conv', 'dec_type': 'lin', 'enc_bias': True, 'dec_bias': False}
#
# Trainer:
# {'method': 'mc', 'kl_beta': 1.0, 'kl_anneal_portion': 0.5, 'lambda_anneal': True, 'lambda_init': 0.0,
# 'lambda_norm': 0.0, 'temp_anneal_portion': 1.0, 'temp_anneal_type': 'exp', 'temp_start': 1.0, 'temp_stop': 0.05,
# 'lr': 0.005, 'epochs': 3600, 'batch_size': 1000, 'optimizer_kws': {'weight_decay': 0.0}, 'grad_clip': 500}

# %%
vae = MODEL_CLASSES[model_type](CFG_CLASSES[model_type](**cfg_vae))
tr = TrainerVAE(vae, ConfigTrainVAE(**cfg_tr), device=device)

vae.print()
print(f"{vae.cfg.name()}\n{tr.cfg.name()}_({vae.timestamp})\n")
tr.show_schedules()
# Out:
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |  PoissonVAE |  1.4 Mil   |
# |     ---     |    ---     |
# |     stem    |    352     |
# |     enc     |  1.2 Mil   |
# |    fc_enc   |   66.0 K   |
# |    fc_dec   |  131.1 K   |
# +-------------+------------+
# poisson_uniform_c(-3)_rmax(1)_DOVES_z-512_k-32_<conv+b|lin>
# mc_b1000-ep3600-lr(0.005)_beta(1:0x0.5)_temp(0.05:exp-1)_gr(500)_(2024_04_30,12:28)

# %%
vae.fc_dec.bias, vae.fc_enc.bias.shape
# Out:
# (None, torch.Size([512]))

# %% [markdown]
# ## Train

# %%
comment = f"Archi-Final_{tr.cfg.name()}"
# comment = tr.cfg.name()
tr.train(comment=comment)
# Out:
# epoch # 3600, avg loss: 163.486930: 100%|█████████████████████| 3600/3600 [3:27:34<00:00,  3.46s/it]

# %%
print(vae)
# Out:
# PoissonVAE(
#   (mse): MSELoss()
#   (stem): Conv2D(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (enc): Sequential(
#     (0): Cell(
#       (skip): Identity()
#       (ops): ModuleList(
#         (0-1): 2 x ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=32, out_features=4, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=32, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (1): Cell(
#       (skip): FactorizedReduce(
#         (swish): SiLU()
#         (ops): ModuleList(
#           (0-3): 4 x Conv2D(32, 16, kernel_size=(1, 1), stride=(2, 2))
#         )
#       )
#       (ops): ModuleList(
#         (0): ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#         (1): ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=64, out_features=4, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=64, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (2): Cell(
#       (skip): Identity()
#       (ops): ModuleList(
#         (0-1): 2 x ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=64, out_features=4, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=64, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (3): Cell(
#       (skip): FactorizedReduce(
#         (swish): SiLU()
#         (ops): ModuleList(
#           (0-3): 4 x Conv2D(64, 32, kernel_size=(1, 1), stride=(2, 2))
#         )
#       )
#       (ops): ModuleList(
#         (0): ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#         (1): ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (4): Cell(
#       (skip): Identity()
#       (ops): ModuleList(
#         (0-1): 2 x ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (5): SiLU(inplace=True)
#     (6): Conv2D(128, 128, kernel_size=(4, 4), stride=(1, 1), padding=valid)
#     (7): Flatten(start_dim=1, end_dim=-1)
#     (8): DenseResLayer(
#       (fc1): Linear(in_features=128, out_features=1024, bias=True)
#       (fc2): Linear(in_features=1024, out_features=128, bias=True)
#       (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (drop): Dropout(p=0.1, inplace=False)
#       (relu): ReLU()
#     )
#   )
#   (fc_enc): Linear(in_features=128, out_features=512, bias=True)
#   (fc_dec): Linear(in_features=512, out_features=256, bias=False)
# )

# %% [markdown]
# ## Eval

# %% [markdown]
# ### Loss vld (freeze)

# %%
data, loss, rates = tr.validate()

_loss = {k: v.mean() for k, v in loss.items()}
_loss['tot'] = _loss['mse'] + _loss['kl']
print(_loss)
# Out:
# {'mse': 133.71977, 'kl': 28.975624, 'kl_diag': 0.05607538, 'tot': 162.6954}

# %%
# Out:
# {'mse': 132.80032, 'kl': 29.794188, 'kl_diag': 0.05768895, 'tot': 162.59451}

# %% [markdown]
# ### Identify dead neurons

# %%
ax = sns.histplot(to_np(vae.log_rates.squeeze()))
ax.set_yscale('log')

# %%
dead_thres = 0.01
dead = np.logical_or(
    loss['kl_diag'] < dead_thres,
    to_np(vae.log_rates.squeeze()) > 1
)
dead.sum()
# Out:
# 4

# %%
bins = np.linspace(0, 91, 92)
ax = sns.histplot(loss['kl_diag'][~dead] * 1000, bins=bins, color='dimgrey', label='alive')
sns.histplot(loss['kl_diag'][dead] * 1000, bins=bins, color='r', label='dead', ax=ax)
ax.axvline(dead_thres * 1000, color='r', ls='--', alpha=0.6)
ax.locator_params(axis='x', nbins=11)
ax.legend()
plt.show()

# %% [markdown]
# ### Spike counts

# %%
lifetime, population, percents = sparse_score(data['z'][:, ~dead], cutoff=0.05)
percents
# Out:
# {'0': 94.4, '1': 4.9, '2+': 0.7}

# %%
fig, ax = create_figure(1, 1, (4.7, 2.8))

max_val = float(list(percents.values())[0])
ax.set(
    xlabel='Spike count',
    ylabel='Portion [%]',
    ylim=(0, (np.ceil(max_val / 10) + 1) * 10),
)
colors = ['tomato' if lbl == '0' else 'dimgrey' for lbl in percents]
bars = ax.bar(percents.keys(), percents.values(), color=colors)

for bar in bars:
    y = bar.get_height()
    x = bar.get_x() + 1.3 * bar.get_width() / 2
    plt.text(x, y + 1, f'{y:0.1f}%', ha='center', va='bottom')

ax.locator_params(axis='y', nbins=5)

ax.grid()
plt.show()

# %%
fig, axes = create_figure(1, 2, (7, 2), layout='constrained')

sns.histplot(lifetime, stat='percent', ax=axes[0])
sns.histplot(population, stat='percent', ax=axes[1])

for i, x2p in enumerate([lifetime, population]):
    _a, _med = np.nanmean(x2p), np.nanmedian(x2p)
    # axes[i].axvline(_med, color='g', ls='--', label=f'median: {_med:0.2f}')
    axes[i].axvline(_a, color='r', ls='--', label=f'avg: {_a:0.2f}')

add_legend(axes)
axes[0].set(title='Lifetime', ylabel='%')
axes[1].set(title='Population', ylabel='')
plt.show()

# %%
tot_nspks = data['z'][:, ~dead].sum(1)
tot_firing = (data['z'][:, ~dead] > 0).mean(1)

min(tot_nspks), max(tot_nspks)
# Out:
# (9.0, 81.0)

# %%
a = np.floor(min(tot_nspks) / 10) * 10
b = np.ceil(max(tot_nspks) / 10) * 10

fig, axes = create_figure(1, 2, (9, 2), layout='constrained')

sns.histplot(tot_nspks, bins=np.linspace(a, b, int(b - a) + 1), kde=True, stat='percent', ax=axes[0])
sns.histplot(tot_firing, bins=np.linspace(0, 1.0, 101), kde=True, stat='percent', ax=axes[1])

_a = tot_nspks.mean()
axes[0].axvline(_a, color='r', ls='--', label=f'avg = {_a:0.1f}    ')
_a = tot_firing.mean()
axes[1].axvline(_a, color='r', ls='--', label=f'avg = {_a:0.3f}    ')

axes[0].axvline(vae.cfg.n_latents, color='k', ls='--')
axes[1].axvline(1.0, color='k', ls='--')

axes[0].set_title('total # spks per stimulus')
axes[1].set(title='portion active neurons per stimulus', ylabel='')

for ax in axes.flat:
    ax.axvline(0, color='k', ls='--')
    ax.legend()
plt.show()

# %% [markdown]
# ### Plot enc/dec weights

# %%
vae.show(dpi=250, order=np.argsort(to_np(vae.log_rates.squeeze())));

# %%
## Previous implementation: without fc encoder layers but with a massive DensReslayer

# %%
vae.show(dpi=150, order=np.argsort(loss['kl_diag']));

# %%
## Previous implementation: without fc encoder layers but with a massive DensReslayer

# %% [markdown]
# ### Some more distributions

# %%
tr.model.temp, tr.cfg.kl_beta
# Out:
# (tensor(0.0505, device='cuda:0'), 1.0)

# %%
prior_rates = to_np(vae.log_rates)[:, ~dead].ravel()

mu = prior_rates.mean()
sd = prior_rates.std()

rv = sp_stats.norm(loc=mu, scale=sd)
xs = np.linspace(-5.5, 0.5, 100)
pdf = rv.pdf(xs)

# %%
fig, ax = create_figure()

sns.histplot(prior_rates, stat='density', bins=100, kde=True, label='log prior rates', ax=ax)
ax.plot(xs, pdf, color='r', lw=2, ls='--', label='lognorm fit')
add_legend(ax)
plt.show()

# %%
vae.log_rates.squeeze()[dead]
# Out:
# tensor([-6.6490, -5.6052, -8.9470,  2.6936], device='cuda:0',
#        grad_fn=<IndexBackward0>)

# %%
loss['kl_diag'][dead]
# Out:
# array([0.00993424, 0.00478765, 0.00011431, 0.08859663], dtype=float32)

# %%
from figures.imgs import plot_weights

# %%
try:
    ind = np.where(loss['kl_diag'] < dead_thres)[0]
    plot_weights(vae.fc_dec.weight.data.T.reshape(-1, 16, 16)[ind], nrows=1, dpi=10);
except ValueError:
    pass

# %%
try:
    ind = np.where(to_np(vae.log_rates.squeeze()) > 1)[0]
    plot_weights(vae.fc_dec.weight.data.T.reshape(-1, 16, 16)[ind], nrows=1, dpi=10);
except ValueError:
    pass

# %%
print(vae)
# Out:
# PoissonVAE(
#   (mse): MSELoss()
#   (stem): Conv2D(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (enc): Sequential(
#     (0): Cell(
#       (skip): Identity()
#       (ops): ModuleList(
#         (0-1): 2 x ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=32, out_features=4, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=32, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (1): Cell(
#       (skip): FactorizedReduce(
#         (swish): SiLU()
#         (ops): ModuleList(
#           (0-3): 4 x Conv2D(32, 16, kernel_size=(1, 1), stride=(2, 2))
#         )
#       )
#       (ops): ModuleList(
#         (0): ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#         (1): ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=64, out_features=4, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=64, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (2): Cell(
#       (skip): Identity()
#       (ops): ModuleList(
#         (0-1): 2 x ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=64, out_features=4, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=64, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (3): Cell(
#       (skip): FactorizedReduce(
#         (swish): SiLU()
#         (ops): ModuleList(
#           (0-3): 4 x Conv2D(64, 32, kernel_size=(1, 1), stride=(2, 2))
#         )
#       )
#       (ops): ModuleList(
#         (0): ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#         (1): ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (4): Cell(
#       (skip): Identity()
#       (ops): ModuleList(
#         (0-1): 2 x ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (5): SiLU(inplace=True)
#     (6): Conv2D(128, 128, kernel_size=(4, 4), stride=(1, 1), padding=valid)
#     (7): Flatten(start_dim=1, end_dim=-1)
#     (8): DenseResLayer(
#       (fc1): Linear(in_features=128, out_features=1024, bias=True)
#       (fc2): Linear(in_features=1024, out_features=128, bias=True)
#       (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (drop): Dropout(p=0.1, inplace=False)
#       (relu): ReLU()
#     )
#   )
#   (fc_enc): Linear(in_features=128, out_features=512, bias=True)
#   (fc_dec): Linear(in_features=512, out_features=256, bias=False)
# )

# %% [markdown]
# ## This was when conv pool 2x-ed the nch
# - but possibly other difference as well

# %%
cfg_vae, cfg_tr = default_configs('DOVES')
cfg_vae['enc_type'] = 'conv'
cfg_vae['enc_bias'] = True
cfg_vae['rmax_q'] = 1.0

print(f"VAE:\n{cfg_vae}\n\nTrainer:\n{cfg_tr}")
# Out:
# VAE:
# {'dataset': 'DOVES', 'prior_clamp': -3.0, 'prior_log_dist': 'uniform', 'rmax_q': 1.0, 'n_latents': 512, 'enc_type':
# 'conv', 'dec_type': 'lin', 'enc_bias': True, 'dec_bias': False}
#
# Trainer:
# {'method': 'mc', 'kl_beta': 1.0, 'kl_anneal_portion': 0.5, 'lambda_anneal': True, 'lambda_init': 0.0,
# 'lambda_norm': 0.0, 'temp_anneal_portion': 1.0, 'temp_anneal_type': 'exp', 'temp_start': 1.0, 'temp_stop': 0.05,
# 'lr': 0.005, 'epochs': 3600, 'batch_size': 1000, 'optimizer_kws': {'weight_decay': 0.0}, 'grad_clip': 500}

# %%
vae = MODEL_CLASSES[model_type](CFG_CLASSES[model_type](**cfg_vae))
tr = TrainerVAE(vae, ConfigTrainVAE(**cfg_tr), device=device)

vae.print()
print(f"{vae.cfg.name()}\n{tr.cfg.name()}_({vae.timestamp})\n")
tr.show_schedules()
# Out:
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |  PoissonVAE |  2.5 Mil   |
# |     ---     |    ---     |
# |     stem    |    352     |
# |     enc     |  2.3 Mil   |
# |    fc_enc   |  131.6 K   |
# |    fc_dec   |  131.1 K   |
# +-------------+------------+
# poisson_uniform_c(-3)_rmax(1)_DOVES_z-512_k-32_<conv+b|lin>
# mc_b1000-ep3600-lr(0.005)_beta(1:0x0.5)_temp(0.05:exp-1)_gr(500)_(2024_04_30,07:22)

# %%
### was with: Conv2D(nch * 4, nch * 4, **kws_conv2d),
# Out:
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |  PoissonVAE |  1.4 Mil   |
# |     ---     |    ---     |
# |     stem    |    352     |
# |     enc     |  1.2 Mil   |
# |    fc_enc   |   66.0 K   |
# |    fc_dec   |  131.1 K   |
# +-------------+------------+
# poisson_uniform_c(-3)_rmax(1)_DOVES_z-512_k-32_<conv+b|lin>
# mc_b1000-ep3600-lr(0.005)_beta(1:0x0.5)_temp(0.05:exp-1)_gr(500)_(2024_04_29,23:26)

# %%
vae.fc_dec.bias, vae.fc_enc.bias.shape
# Out:
# (None, torch.Size([512]))

# %% [markdown]
# ### Train

# %%
# comment = f"..._{tr.cfg.name()}"
comment = tr.cfg.name()
tr.train(comment=comment)
# Out:
# epoch # 3600, avg loss: 163.205147: 100%|█████████████████████| 3600/3600 [4:04:23<00:00,  4.07s/it]

# %%
print(vae)
# Out:
# PoissonVAE(
#   (mse): MSELoss()
#   (stem): Conv2D(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (enc): Sequential(
#     (0): Cell(
#       (skip): Identity()
#       (ops): ModuleList(
#         (0-1): 2 x ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=32, out_features=4, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=32, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (1): Cell(
#       (skip): FactorizedReduce(
#         (swish): SiLU()
#         (ops): ModuleList(
#           (0-3): 4 x Conv2D(32, 16, kernel_size=(1, 1), stride=(2, 2))
#         )
#       )
#       (ops): ModuleList(
#         (0): ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#         (1): ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=64, out_features=4, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=64, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (2): Cell(
#       (skip): Identity()
#       (ops): ModuleList(
#         (0-1): 2 x ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=64, out_features=4, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=64, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (3): Cell(
#       (skip): FactorizedReduce(
#         (swish): SiLU()
#         (ops): ModuleList(
#           (0-3): 4 x Conv2D(64, 32, kernel_size=(1, 1), stride=(2, 2))
#         )
#       )
#       (ops): ModuleList(
#         (0): ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#         (1): ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (4): Cell(
#       (skip): Identity()
#       (ops): ModuleList(
#         (0-1): 2 x ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (5): SiLU(inplace=True)
#     (6): Conv2D(128, 256, kernel_size=(4, 4), stride=(1, 1), padding=valid)
#     (7): Flatten(start_dim=1, end_dim=-1)
#     (8): DenseResLayer(
#       (fc1): Linear(in_features=256, out_features=2048, bias=True)
#       (fc2): Linear(in_features=2048, out_features=256, bias=True)
#       (layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (drop): Dropout(p=0.1, inplace=False)
#       (relu): ReLU()
#     )
#   )
#   (fc_enc): Linear(in_features=256, out_features=512, bias=True)
#   (fc_dec): Linear(in_features=512, out_features=256, bias=False)
# )

# %%
### was with: Conv2D(nch * 4, nch * 4, **kws_conv2d),
# Out:
# PoissonVAE(
#   (mse): MSELoss()
#   (stem): Conv2D(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (enc): Sequential(
#     (0): Cell(
#       (skip): Identity()
#       (ops): ModuleList(
#         (0-1): 2 x ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=32, out_features=4, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=32, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (1): Cell(
#       (skip): FactorizedReduce(
#         (swish): SiLU()
#         (ops): ModuleList(
#           (0-3): 4 x Conv2D(32, 16, kernel_size=(1, 1), stride=(2, 2))
#         )
#       )
#       (ops): ModuleList(
#         (0): ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#         (1): ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=64, out_features=4, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=64, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (2): Cell(
#       (skip): Identity()
#       (ops): ModuleList(
#         (0-1): 2 x ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=64, out_features=4, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=64, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (3): Cell(
#       (skip): FactorizedReduce(
#         (swish): SiLU()
#         (ops): ModuleList(
#           (0-3): 4 x Conv2D(64, 32, kernel_size=(1, 1), stride=(2, 2))
#         )
#       )
#       (ops): ModuleList(
#         (0): ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#         (1): ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (4): Cell(
#       (skip): Identity()
#       (ops): ModuleList(
#         (0-1): 2 x ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (5): SiLU(inplace=True)
#     (6): Conv2D(128, 128, kernel_size=(4, 4), stride=(1, 1), padding=valid)
#     (7): Flatten(start_dim=1, end_dim=-1)
#     (8): DenseResBlock(
#       (fc1): Linear(in_features=128, out_features=1024, bias=True)
#       (fc2): Linear(in_features=1024, out_features=128, bias=True)
#       (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (drop): Dropout(p=0.1, inplace=False)
#       (relu): ReLU()
#     )
#   )
#   (fc_enc): Linear(in_features=128, out_features=512, bias=True)
#   (fc_dec): Linear(in_features=512, out_features=256, bias=False)
# )

# %% [markdown]
# ### Eval

# %% [markdown]
# ### Loss vld (freeze)

# %%
data, loss, rates = tr.validate()

_loss = {k: v.mean() for k, v in loss.items()}
_loss['tot'] = _loss['mse'] + _loss['kl']
print(_loss)
# Out:
# {'mse': 132.80032, 'kl': 29.794188, 'kl_diag': 0.05768895, 'tot': 162.59451}

# %%
### was with: Conv2D(nch * 4, nch * 4, **kws_conv2d),
# Out:
# {'mse': 133.80302, 'kl': 28.962217, 'kl_diag': 0.056041546, 'tot': 162.76524}

# %% [markdown]
# ### Identify dead neurons

# %%
ax = sns.histplot(to_np(vae.log_rates.squeeze()))
ax.set_yscale('log')

# %%
### was with: Conv2D(nch * 4, nch * 4, **kws_conv2d),

# %%
dead_thres = 0.01
dead = np.logical_or(
    loss['kl_diag'] < dead_thres,
    to_np(vae.log_rates.squeeze()) > 1
)
dead.sum()
# Out:
# 1

# %%
bins = np.linspace(0, 91, 92)
ax = sns.histplot(loss['kl_diag'][~dead] * 1000, bins=bins, color='dimgrey', label='alive')
sns.histplot(loss['kl_diag'][dead] * 1000, bins=bins, color='r', label='dead', ax=ax)
ax.axvline(dead_thres * 1000, color='r', ls='--', alpha=0.6)
ax.locator_params(axis='x', nbins=11)
ax.legend()
plt.show()

# %%
### was with: Conv2D(nch * 4, nch * 4, **kws_conv2d),

# %% [markdown]
# ### Spike counts

# %%
lifetime, population, percents = sparse_score(data['z'][:, ~dead], cutoff=0.05)
percents
# Out:
# {'0': 94.1, '1': 5.0, '2': 0.6, '3+': 0.2}

# %%
### was with: Conv2D(nch * 4, nch * 4, **kws_conv2d),

# %%
fig, ax = create_figure(1, 1, (4.7, 2.8))

max_val = float(list(percents.values())[0])
ax.set(
    xlabel='Spike count',
    ylabel='Portion [%]',
    ylim=(0, (np.ceil(max_val / 10) + 1) * 10),
)
colors = ['tomato' if lbl == '0' else 'dimgrey' for lbl in percents]
bars = ax.bar(percents.keys(), percents.values(), color=colors)

for bar in bars:
    y = bar.get_height()
    x = bar.get_x() + 1.3 * bar.get_width() / 2
    plt.text(x, y + 1, f'{y:0.1f}%', ha='center', va='bottom')

ax.locator_params(axis='y', nbins=5)

ax.grid()
plt.show()

# %%
fig, axes = create_figure(1, 2, (7, 2), layout='constrained')

sns.histplot(lifetime, stat='percent', ax=axes[0])
sns.histplot(population, stat='percent', ax=axes[1])

for i, x2p in enumerate([lifetime, population]):
    _a, _med = np.nanmean(x2p), np.nanmedian(x2p)
    # axes[i].axvline(_med, color='g', ls='--', label=f'median: {_med:0.2f}')
    axes[i].axvline(_a, color='r', ls='--', label=f'avg: {_a:0.2f}')

add_legend(axes)
axes[0].set(title='Lifetime', ylabel='%')
axes[1].set(title='Population', ylabel='')
plt.show()

# %%
### was with: Conv2D(nch * 4, nch * 4, **kws_conv2d),

# %%
tot_nspks = data['z'][:, ~dead].sum(1)
tot_firing = (data['z'][:, ~dead] > 0).mean(1)

min(tot_nspks), max(tot_nspks)
# Out:
# (9.0, 73.0)

# %%
a = np.floor(min(tot_nspks) / 10) * 10
b = np.ceil(max(tot_nspks) / 10) * 10

fig, axes = create_figure(1, 2, (9, 2), layout='constrained')

sns.histplot(tot_nspks, bins=np.linspace(a, b, int(b - a) + 1), kde=True, stat='percent', ax=axes[0])
sns.histplot(tot_firing, bins=np.linspace(0, 1.0, 101), kde=True, stat='percent', ax=axes[1])

_a = tot_nspks.mean()
axes[0].axvline(_a, color='r', ls='--', label=f'avg = {_a:0.1f}    ')
_a = tot_firing.mean()
axes[1].axvline(_a, color='r', ls='--', label=f'avg = {_a:0.3f}    ')

axes[0].axvline(vae.cfg.n_latents, color='k', ls='--')
axes[1].axvline(1.0, color='k', ls='--')

axes[0].set_title('total # spks per stimulus')
axes[1].set(title='portion active neurons per stimulus', ylabel='')

for ax in axes.flat:
    ax.axvline(0, color='k', ls='--')
    ax.legend()
plt.show()

# %% [markdown]
# ### Plot enc/dec weights

# %%
vae.show(dpi=250, order=np.argsort(to_np(vae.log_rates.squeeze())));

# %%
### was with: Conv2D(nch * 4, nch * 4, **kws_conv2d),

# %%
vae.show(dpi=150, order=np.argsort(loss['kl_diag']));

# %%
### was with: Conv2D(nch * 4, nch * 4, **kws_conv2d),

# %% [markdown]
# ### Some more distributions

# %%
tr.model.temp, tr.cfg.kl_beta
# Out:
# (tensor(0.0505, device='cuda:0'), 1.0)

# %%
prior_rates = to_np(vae.log_rates)[:, ~dead].ravel()

mu = prior_rates.mean()
sd = prior_rates.std()

rv = sp_stats.norm(loc=mu, scale=sd)
xs = np.linspace(-5.5, 0.5, 100)
pdf = rv.pdf(xs)

# %%
fig, ax = create_figure()

sns.histplot(prior_rates, stat='density', bins=100, kde=True, label='log prior rates', ax=ax)
ax.plot(xs, pdf, color='r', lw=2, ls='--', label='lognorm fit')
add_legend(ax)
plt.show()

# %%
### was with: Conv2D(nch * 4, nch * 4, **kws_conv2d),

# %%
vae.log_rates.squeeze()[dead]
# Out:
# tensor([2.6646], device='cuda:0', grad_fn=<IndexBackward0>)

# %%
loss['kl_diag'][dead]
# Out:
# array([0.08601142], dtype=float32)

# %%
from figures.imgs import plot_weights

# %%
try:
    ind = np.where(loss['kl_diag'] < dead_thres)[0]
    plot_weights(vae.fc_dec.weight.data.T.reshape(-1, 16, 16)[ind], nrows=1, dpi=10);
except ValueError:
    pass

# %%
ind = np.where(to_np(vae.log_rates.squeeze()) > 1)[0]
plot_weights(vae.fc_dec.weight.data.T.reshape(-1, 16, 16)[ind], nrows=1, dpi=10);

# %%
print(vae)
# Out:
# PoissonVAE(
#   (mse): MSELoss()
#   (stem): Conv2D(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (enc): Sequential(
#     (0): Cell(
#       (skip): Identity()
#       (ops): ModuleList(
#         (0-1): 2 x ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=32, out_features=4, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=32, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (1): Cell(
#       (skip): FactorizedReduce(
#         (swish): SiLU()
#         (ops): ModuleList(
#           (0-3): 4 x Conv2D(32, 16, kernel_size=(1, 1), stride=(2, 2))
#         )
#       )
#       (ops): ModuleList(
#         (0): ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#         (1): ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=64, out_features=4, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=64, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (2): Cell(
#       (skip): Identity()
#       (ops): ModuleList(
#         (0-1): 2 x ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=64, out_features=4, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=64, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (3): Cell(
#       (skip): FactorizedReduce(
#         (swish): SiLU()
#         (ops): ModuleList(
#           (0-3): 4 x Conv2D(64, 32, kernel_size=(1, 1), stride=(2, 2))
#         )
#       )
#       (ops): ModuleList(
#         (0): ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#         (1): ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (4): Cell(
#       (skip): Identity()
#       (ops): ModuleList(
#         (0-1): 2 x ConvLayer(
#           (act_fn): SiLU()
#           (conv): Conv2D(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SELayer(
#         (fc): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (5): SiLU(inplace=True)
#     (6): Conv2D(128, 256, kernel_size=(4, 4), stride=(1, 1), padding=valid)
#     (7): Flatten(start_dim=1, end_dim=-1)
#     (8): DenseResLayer(
#       (fc1): Linear(in_features=256, out_features=2048, bias=True)
#       (fc2): Linear(in_features=2048, out_features=256, bias=True)
#       (layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (drop): Dropout(p=0.1, inplace=False)
#       (relu): ReLU()
#     )
#   )
#   (fc_enc): Linear(in_features=256, out_features=512, bias=True)
#   (fc_dec): Linear(in_features=512, out_features=256, bias=False)
# )

# %% [markdown]
# ## The end
