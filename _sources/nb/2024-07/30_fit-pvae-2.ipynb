# %% [markdown]
# # (30) fit pvae
#
# **Motivation**: host = ```mach```, device = ```cuda:2``` <br>

# %%
# HIDE CODE


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-vae/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-vae/figs')
tmp_dir = os.path.join(git_dir, 'jb-vae/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_PoissonVAE'))
from figures.fighelper import *
from vae.train_vae import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %%
from base.utils_model import load_quick

device_idx = 2
device = f'cuda:{device_idx}'

# %% [markdown]
# ## Fit one model

# %% [markdown]
# ### Get configs

# %%
model_type = 'poisson'
cfg_vae, cfg_tr = default_configs('vH16', model_type, 'lin|lin')
cfg_tr['temp_stop'] = 0.1

print(f"VAE:\n{cfg_vae}\n\nTrainer:\n{cfg_tr}")
# Out:
# VAE:
# {'dataset': 'vH16', 'n_ch': 32, 'n_latents': 512, 'prior_clamp': -4, 'fit_prior': True, 'enc_type': 'lin',
# 'dec_type': 'lin', 'enc_bias': False, 'dec_bias': False, 'init_dist': 'Normal', 'init_scale': 0.05}
#
# Trainer:
# {'lr': 0.005, 'batch_size': 1000, 'epochs': 3000, 'optimizer_kws': {'weight_decay': 0.0}, 'grad_clip': 500,
# 'kl_const_portion': 0.0, 'temp_stop': 0.1}

# %% [markdown]
# ### Make model + trainer

# %%
vae = MODEL_CLASSES[model_type](CFG_CLASSES[model_type](**cfg_vae))
tr = TrainerVAE(vae, ConfigTrainVAE(**cfg_tr), device=device)

# %% [markdown]
# ### Print info

# %%
vae.print()
print(f"{vae.cfg.name()}\n{tr.cfg.name()}_({vae.timestamp})\n")
tr.show_schedules()
# Out:
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |  PoissonVAE |  262.7 K   |
# |     ---     |    ---     |
# |    fc_enc   |  131.1 K   |
# |    fc_dec   |  131.1 K   |
# +-------------+------------+
# poisson_uniform_c(-4)_vH16_z-512_fp_nrm-none_<lin|lin>
# mc_b1000-ep3000-lr(0.005)_beta(1:0x0.5)_temp(0.1:lin-0.5)_gr(500)_(2024_07_30,14:32)

# %% [markdown]
# ### Fit model

# %%
tr.train()
# Out:
# epoch # 3000, avg loss: 163.766974: 100%|████████████████████████████████████████████████████| 3000/3000 [1:49:41<00:00,  2.19s/it]

# %% [markdown]
# ### Loss

# %%
data, loss, etc = tr.validate(full_data=True)
kl_diag = loss['kl_diag']
order = np.argsort(kl_diag)
loss = {
    k: np.mean(v) for k, v in
    loss.items() if k != 'kl_diag'
}
loss['nelbo'] = loss['mse'] + loss['kl']
print(loss)
# Out:
# {'mse': 135.71948, 'kl': 32.539417, 'nelbo': 168.2589}

# %% [markdown]
# ### Visualize

# %%
tr.model.show('dec', order=order)
tr.model.show('enc', order=order);

# %% [markdown]
# ## Load model

# %%
root = add_home('Dropbox/chkpts/PoissonVAE')

models2load = {
    'poisson': 'poisson-<lin|lin>-vH16-nrm-none_soft+t0.1_chewie-1_(2024_07_26,18/06)',
}
models2load = {k: v.replace('/', ':') for k, v in models2load.items()}

# %%
trainers = {}
for name, load_path in models2load.items():
    try:
        trainers[name], _ = load_quick(
            pjoin(root, load_path),
            lite=True,
            device=device,
            verbose=True,
        )
    except FileNotFoundError:
        continue
# Out:
# # params: 262.7 K

# %%
tr = trainers['poisson']
data, loss, etc = tr.validate(full_data=True)
order = np.argsort(loss['kl_diag'])

# %%
tr.model.show('dec', order=order)
tr.model.show('enc', order=order);
