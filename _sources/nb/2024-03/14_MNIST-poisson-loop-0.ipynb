# %% [markdown]
# # (14) MNIST — Poisson (Loop) — 0
#
# **Motivation**: Hyperparam sweep, PoissonVAE. Device = ```cuda:0``` <br>

# %%
# HIDE CODE


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-vae/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-vae/figs')
tmp_dir = os.path.join(git_dir, 'jb-vae/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_PoissonVAE'))
from figures.fighelper import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %% [markdown]
# ## Import $/$ prep

# %%
from _tmp.mnist import iteration
from _tmp.gapvae import prepare_stuff, validate
from _tmp.plotters import plot_latent_space, plot_latent_scatter

from torchvision.utils import make_grid

# %%
batch_size = 200
epochs = 300

kws = dict(
    n_latents=None,
    beta=None,
    device_idx=0,
    model='pvae',
    activation='exp',
    weight_norm=True,
    max_grad_norm=300,
    batch_size=batch_size,
    epochs=epochs,
    lr=1e-3,
)

# %%
# %%time

results = collections.defaultdict(dict)
n_latents = [10, 50, 100, 1000, 5000]
betas = [0.1, 0.4] #, 0.7, 1.0]
looper = itertools.product(n_latents, betas)
# looper = tqdm(looper, ncols=130, position=0)
for n, b in looper:
    key = (n, b)
    # looper.set_description(f'n = {n} —— beta = {b:0.1f}')

    kws['n_latents'], kws['beta'] = n, b
    pvae, optim, optim_schedule, trn, vld, device, kws_iter = prepare_stuff(**kws)

    pbar = tqdm(range(epochs), ncols=138, position=0, leave=True)
    for ep in pbar:
        grad, tot, recon, kl = iteration(
            ep, pvae, trn, optim, optim_schedule, device, **kws_iter)

        msg = ',  '.join([
            f"latents, beta = ({n}, {b:0.1f})",
            f"grad = {grad:0.1f}",
            f"loss = (kl: {kl:0.1f}, recon: {recon:0.1f}  ——  tot: {tot:0.2f})  ",
        ])
        pbar.set_description(msg)

    
    emb, labels, loss_vld = validate(pvae, vld, device)
    results['loss_vld'][key] = loss_vld.copy()

    
    spks, r_q, r_p, r_qp = [], [], [], []
    for x, _ in iter(vld):
        x = x.to(device)
        with torch.inference_mode():
            out = pvae(x)
        spks.append(to_np(out['spks']))
        r_q.append(to_np(out['r_q']))
        r_p.append(to_np(out['r_p']))
        r_qp.append(to_np(out['r_q'] * out['r_p']))
    
    spks, r_q, r_p, r_qp = cat_map([spks, r_q, r_p, r_qp])
    results['spks'][key] = spks.copy()
    results['r_q'][key] = r_q.copy()
    results['r_p'][key] = r_p.copy()
    results['r_qp'][key] = r_qp.copy()

    
    fig, axes = create_figure(2, 2, (8, 4.5), layout='constrained')
    nbins = 500
    _kws = dict(
        legend=False, 
        stat='percent',
        bins=np.linspace(0, nbins, nbins+1) - 0.5,
        color='k',
    )
    sns.histplot(spks.ravel(),  ax=axes[0, 0], **_kws)
    _kws = dict(
        kde=True,
        legend=False, 
        stat='percent',
        line_kws={'lw': 2},
        alpha=0.2,
    )
    sns.histplot(r_q.ravel(), ax=axes[1, 0], **_kws)
    sns.histplot(np.log(r_qp.ravel()),  ax=axes[0, 1], **_kws)
    sns.histplot(np.log(r_p.ravel()), ax=axes[1, 1], **_kws)
    
    axes[0, 0].set_title('Spike counts')
    axes[0, 1].set_title(r'$r \delta r$' + ' (posterior)')
    
    axes[1, 0].set_title(r'$\delta r$' + ' (encoder output)')
    axes[1, 1].set_title(r'$r$' + ' (from prior)')

    for ax in axes[:, 1]:
        ax.set_ylabel('')
    
    add_grid(axes)
    
    plt.show()

    
    x_samples = pvae.sample(50)
    grid_images = make_grid(x_samples, nrow=10, normalize=True, value_range=(0, 1))

    x2p = to_np(grid_images)
    x2p = np.transpose(x2p, (1, 2, 0))
    
    fig, ax = create_figure(1, 1, (10, 3))
    ax.imshow(x2p)
    remove_ticks(ax)
    plt.show()

    
    x, _ = next(iter(vld))
    x = x.to(device)
    with torch.inference_mode():
        out = pvae(x)
    
    num = 32
    grid_images = make_grid(
        torch.cat([x[:num], out['x_recon'][:num]]),
        nrow=num,
        normalize=True,
        value_range=(0, 1),
    )
    
    x2p = to_np(grid_images)
    x2p = np.transpose(x2p, (1, 2, 0))
    
    fig, ax = create_figure(1, 1, (13, 5))
    ax.imshow(x2p)
    remove_ticks(ax)
    plt.show()
# Out:
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |  PoissonVAE |  7.8 Mil   |
# |     ---     |    ---     |
# |     enc     |  6.6 Mil   |
# |     dec     |  1.2 Mil   |
# +-------------+------------+
# latents, beta = (10, 0.1),  grad = 388.0,  loss = (kl: 54.5, recon: 14.4  ——  tot: 19.82)  : 100%|██████| 300/300 [59:50<00:00, 11.97s/it]
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |  PoissonVAE |  7.8 Mil   |
# |     ---     |    ---     |
# |     enc     |  6.6 Mil   |
# |     dec     |  1.2 Mil   |
# +-------------+------------+
# latents, beta = (10, 0.4),  grad = 138.9,  loss = (kl: 20.0, recon: 22.0  ——  tot: 30.04)  : 100%|██████| 300/300 [59:53<00:00, 11.98s/it]
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |  PoissonVAE |  7.9 Mil   |
# |     ---     |    ---     |
# |     enc     |  6.6 Mil   |
# |     dec     |  1.3 Mil   |
# +-------------+------------+
# latents, beta = (50, 0.1),  grad = 150.7,  loss = (kl: 53.2, recon: 10.6  ——  tot: 15.96)  : 100%|██████| 300/300 [59:47<00:00, 11.96s/it]
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |  PoissonVAE |  7.9 Mil   |
# |     ---     |    ---     |
# |     enc     |  6.6 Mil   |
# |     dec     |  1.3 Mil   |
# +-------------+------------+
# latents, beta = (50, 0.4),  grad = 160.2,  loss = (kl: 22.3, recon: 17.4  ——  tot: 26.28)  : 100%|██████| 300/300 [59:46<00:00, 11.96s/it]
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |  PoissonVAE |  7.9 Mil   |
# |     ---     |    ---     |
# |     enc     |  6.6 Mil   |
# |     dec     |  1.3 Mil   |
# +-------------+------------+
# latents, beta = (100, 0.1),  grad = 134.7,  loss = (kl: 53.6, recon: 10.3  ——  tot: 15.64)  : 100%|█████| 300/300 [59:51<00:00, 11.97s/it]
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |  PoissonVAE |  7.9 Mil   |
# |     ---     |    ---     |
# |     enc     |  6.6 Mil   |
# |     dec     |  1.3 Mil   |
# +-------------+------------+
# latents, beta = (100, 0.4),  grad = 141.5,  loss = (kl: 22.6, recon: 16.7  ——  tot: 25.69)  : 100%|█████| 300/300 [59:00<00:00, 11.80s/it]
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |  PoissonVAE |  8.9 Mil   |
# |     ---     |    ---     |
# |     enc     |  6.6 Mil   |
# |     dec     |  2.3 Mil   |
# +-------------+------------+
# latents, beta = (1000, 0.1),  grad = 130.7,  loss = (kl: 54.1, recon: 10.5  ——  tot: 15.88)  : 100%|██| 300/300 [1:01:06<00:00, 12.22s/it]
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |  PoissonVAE |  8.9 Mil   |
# |     ---     |    ---     |
# |     enc     |  6.6 Mil   |
# |     dec     |  2.3 Mil   |
# +-------------+------------+
# latents, beta = (1000, 0.4),  grad = 134.9,  loss = (kl: 22.7, recon: 17.1  ——  tot: 26.21)  : 100%|██| 300/300 [1:02:44<00:00, 12.55s/it]
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |  PoissonVAE |  13.1 Mil  |
# |     ---     |    ---     |
# |     enc     |  6.7 Mil   |
# |     dec     |  6.4 Mil   |
# +-------------+------------+
# latents, beta = (5000, 0.1),  grad = 102.0,  loss = (kl: 53.6, recon: 11.6  ——  tot: 16.93)  :  85%|███▍| 255/300 [51:49<09:31, 12.70s/it]/opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [384,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [385,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [386,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [387,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [388,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [389,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [390,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [391,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [392,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [393,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [394,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [395,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [396,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [397,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [398,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [399,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [400,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [401,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [402,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [403,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [404,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [405,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [406,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [407,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [408,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [409,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [410,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [411,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [412,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [413,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [414,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/cuda/Distributions.cu:50: operator(): block: [20,0,0], thread: [415,0,0] Assertion `lambda >= 0 && "invalid Poisson rate, expected rate to be non-negative"` failed.
# latents, beta = (5000, 0.1),  grad = 102.0,  loss = (kl: 53.6, recon: 11.6  ——  tot: 16.93)  :  85%|███▍| 255/300 [51:50<09:08, 12.20s/it]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File <timed exec>:15
#
# File ~/Dropbox/git/_PoissonVAE/_tmp/mnist.py:271, in iteration(epoch, model, trn, optim, optim_schedule, device, **kwargs)
#     268 loss = loss_dict['tot'] / len(x)
#     270 # backward
# --> 271 loss.backward()
#     273 # grad clip
#     274 if gstep < kwargs['n_iters_warmup']:
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/autograd/__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
save_obj(
    obj=results,
    file_name=f'results0_{now()}',
    save_dir=tmp_dir,
    mode='npy',
);
# Out:
# [PROGRESS] 'results0_2024_03_17.npy' saved at
# /home/hadi/Dropbox/git/jb-vae/tmp

# %% [markdown]
# ## Plot results

# %%
df = []
for (n, b), _d in results['loss_vld'].items():
    d = _d.copy()
    d['nelbo'] = d['recon'] + d['kl']

    df.append({
        'n_latents': [n] * len(d),
        'beta': [b] * len(d),
        'label': d.keys(),
        'value': d.values(),
    })
df = pd.DataFrame(merge_dicts(df))

# %%
fg = sns.catplot(data=df, x='n_latents', y='value', hue='label', col='beta', kind='bar', height=3, aspect=1.2)
plt.show()

# %%
fig, axes = create_figure(1, 2, (9, 3), layout='constrained')

sns.barplot(data=df.loc[df['label'] == 'nelbo'], x='n_latents', y='value', hue='beta', ax=axes[0])
axes[0].set_ylabel('NELBO')
axes[0].set_ylim(bottom=35, top=70)
sns.move_legend(axes[0], loc='upper center')

sns.barplot(data=df.loc[df['label'] == 'recon'], x='n_latents', y='value', hue='beta', ax=axes[1])
axes[1].set_ylabel('Recunstruction')
axes[1].set_ylim(bottom=9, top=25)
sns.move_legend(axes[1], loc='upper center')
plt.show()
